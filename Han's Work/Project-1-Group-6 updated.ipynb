# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
file = "caffeine.csv"
df=pd.read_csv(file)
df
# Out:
#                            drink  Volume (ml)  Calories  Caffeine (mg)    type
# 0                   Costa Coffee   256.993715         0            277  Coffee
# 1    Coffee Friend Brewed Coffee   250.191810         0            145  Coffee
# 2             Hell Energy Coffee   250.191810       150            100  Coffee
# 3             Killer Coffee (AU)   250.191810         0            430  Coffee
# 4                   Nescafe Gold   250.191810         0             66  Coffee
# ..                           ...          ...       ...            ...     ...
# 605     Pep Talk Sparkling Water   354.882000         0             55   Water
# 606          Polar Seltzer Water   354.882000         0              0   Water
# 607       Yerbae Sparkling Water   354.882000         0            100   Water
# 608                  Tonic Water   295.735000       110              0   Water
# 609    MiO Energy Water Enhancer   236.588000         0             60   Water
#
# [610 rows x 5 columns]

# %%
df2=df.copy()

# %%
df2['caffeine_per_100ml']= df2["Caffeine (mg)"]/df2["Volume (ml)"]*100
df2
# Out:
#                            drink  Volume (ml)  Calories  Caffeine (mg)  \
# 0                   Costa Coffee   256.993715         0            277
# 1    Coffee Friend Brewed Coffee   250.191810         0            145
# 2             Hell Energy Coffee   250.191810       150            100
# 3             Killer Coffee (AU)   250.191810         0            430
# 4                   Nescafe Gold   250.191810         0             66
# ..                           ...          ...       ...            ...
# 605     Pep Talk Sparkling Water   354.882000         0             55
# 606          Polar Seltzer Water   354.882000         0              0
# 607       Yerbae Sparkling Water   354.882000         0            100
# 608                  Tonic Water   295.735000       110              0
# 609    MiO Energy Water Enhancer   236.588000         0             60
#
#        type  caffeine_per_100ml
# 0    Coffee          107.784737
# 1    Coffee           57.955534
# 2    Coffee           39.969334
# 3    Coffee          171.868136
# 4    Coffee           26.379760
# ..      ...                 ...
# 605   Water           15.498109
# 606   Water            0.000000
# 607   Water           28.178380
# 608   Water            0.000000
# 609   Water           25.360542
#
# [610 rows x 6 columns]

# %%
df2['calories_per_100ml']= df2["Calories"]/df2["Volume (ml)"]*100
df2
# Out:
#                            drink  Volume (ml)  Calories  Caffeine (mg)  \
# 0                   Costa Coffee   256.993715         0            277
# 1    Coffee Friend Brewed Coffee   250.191810         0            145
# 2             Hell Energy Coffee   250.191810       150            100
# 3             Killer Coffee (AU)   250.191810         0            430
# 4                   Nescafe Gold   250.191810         0             66
# ..                           ...          ...       ...            ...
# 605     Pep Talk Sparkling Water   354.882000         0             55
# 606          Polar Seltzer Water   354.882000         0              0
# 607       Yerbae Sparkling Water   354.882000         0            100
# 608                  Tonic Water   295.735000       110              0
# 609    MiO Energy Water Enhancer   236.588000         0             60
#
#        type  caffeine_per_100ml  calories_per_100ml
# 0    Coffee          107.784737            0.000000
# 1    Coffee           57.955534            0.000000
# 2    Coffee           39.969334           59.954001
# 3    Coffee          171.868136            0.000000
# 4    Coffee           26.379760            0.000000
# ..      ...                 ...                 ...
# 605   Water           15.498109            0.000000
# 606   Water            0.000000            0.000000
# 607   Water           28.178380            0.000000
# 608   Water            0.000000           37.195462
# 609   Water           25.360542            0.000000
#
# [610 rows x 7 columns]

# %%
df2.columns
# Out:
# Index(['drink', 'Volume (ml)', 'Calories', 'Caffeine (mg)', 'type',
#        'caffeine_per_100ml', 'calories_per_100ml'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   drink          610 non-null    object
#  1   Volume (ml)    610 non-null    float64
#  2   Calories       610 non-null    int64
#  3   Caffeine (mg)  610 non-null    int64
#  4   type           610 non-null    object
# dtypes: float64(1), int64(2), object(2)
# memory usage: 24.0+ KB

# %%
df.type.unique()
# Out:
# array(['Coffee', 'Energy Drinks', 'Energy Shots', 'Soft Drinks', 'Tea',
#        'Water'], dtype=object)

# %%
#df.drink.unique()

# %%
#df.drink.sort_values().unique()

# %%
df.type.sort_values()
# Out:
# 0      Coffee
# 111    Coffee
# 112    Coffee
# 113    Coffee
# 114    Coffee
#         ...
# 585     Water
# 584     Water
# 608     Water
# 595     Water
# 609     Water
# Name: type, Length: 610, dtype: object

# %%
df.type.value_counts()
# Out:
# Energy Drinks    219
# Coffee           173
# Soft Drinks       90
# Tea               66
# Energy Shots      36
# Water             26
# Name: type, dtype: int64

# %%
df.drink.value_counts()
# Out:
# Costa Coffee                 1
# Redline Xtreme Shot          1
# Equip Pure Energy Shot       1
# Mana Energy Potion           1
# Clif Shot Energy Gel         1
#                             ..
# V Energy Drink               1
# XL Energy Drink (EU)         1
# Crave Energy Drink (UK)      1
# Bomba (EU)                   1
# MiO Energy Water Enhancer    1
# Name: drink, Length: 610, dtype: int64

# %%
grouped_df=df.groupby(["type"])
grouped_df.head(100)
# Out:
#                            drink  Volume (ml)  Calories  Caffeine (mg)    type
# 0                   Costa Coffee   256.993715         0            277  Coffee
# 1    Coffee Friend Brewed Coffee   250.191810         0            145  Coffee
# 2             Hell Energy Coffee   250.191810       150            100  Coffee
# 3             Killer Coffee (AU)   250.191810         0            430  Coffee
# 4                   Nescafe Gold   250.191810         0             66  Coffee
# ..                           ...          ...       ...            ...     ...
# 605     Pep Talk Sparkling Water   354.882000         0             55   Water
# 606          Polar Seltzer Water   354.882000         0              0   Water
# 607       Yerbae Sparkling Water   354.882000         0            100   Water
# 608                  Tonic Water   295.735000       110              0   Water
# 609    MiO Energy Water Enhancer   236.588000         0             60   Water
#
# [418 rows x 5 columns]

# %%
df.columns
# Out:
# Index(['drink', 'Volume (ml)', 'Calories', 'Caffeine (mg)', 'type'], dtype='object')

# %%
df1=df.groupby("type")[['Volume (ml)','Calories','Caffeine (mg)']].mean().reset_index()
df1.head()
# Out:
#             type  Volume (ml)    Calories  Caffeine (mg)
# 0         Coffee   335.870855   73.497110     200.589595
# 1  Energy Drinks   388.971198   86.671233     147.867580
# 2   Energy Shots    57.742259   16.500000     193.416667
# 3    Soft Drinks   355.243454  111.111111      33.677778
# 4            Tea   360.474080   52.757576      55.863636

# %%
caffeine_per_100ml=df1["Caffeine (mg)"]/df1["Volume (ml)"]*100
caffeine_per_100ml
# Out:
# 0     59.722239
# 1     38.015046
# 2    334.965536
# 3      9.480197
# 4     15.497269
# 5     13.616857
# dtype: float64

# %%
# calories_per_100ml=df1["Calories"]/df1["Volume (ml)"]*100
# calories_per_100ml

# %%
df1['caffeine_per_100ml']= df1["Caffeine (mg)"]/df1["Volume (ml)"]*100

# %%
df1
# Out:
#             type  Volume (ml)    Calories  Caffeine (mg)  caffeine_per_100ml
# 0         Coffee   335.870855   73.497110     200.589595           59.722239
# 1  Energy Drinks   388.971198   86.671233     147.867580           38.015046
# 2   Energy Shots    57.742259   16.500000     193.416667          334.965536
# 3    Soft Drinks   355.243454  111.111111      33.677778            9.480197
# 4            Tea   360.474080   52.757576      55.863636           15.497269
# 5          Water   394.590111   11.538462      53.730769           13.616857

# %%
df1['calories_per_100ml']= df1["Calories"]/df1["Volume (ml)"]*100

# %%
df1.head()
# Out:
#             type  Volume (ml)    Calories  Caffeine (mg)  caffeine_per_100ml  \
# 0         Coffee   335.870855   73.497110     200.589595           59.722239
# 1  Energy Drinks   388.971198   86.671233     147.867580           38.015046
# 2   Energy Shots    57.742259   16.500000     193.416667          334.965536
# 3    Soft Drinks   355.243454  111.111111      33.677778            9.480197
# 4            Tea   360.474080   52.757576      55.863636           15.497269
#
#    calories_per_100ml
# 0           21.882551
# 1           22.282172
# 2           28.575259
# 3           31.277455
# 4           14.635609

# %%
df1.corr()
# Out:
#                     Volume (ml)  Calories  Caffeine (mg)  caffeine_per_100ml  \
# Volume (ml)            1.000000  0.447615      -0.554659           -0.984828
# Calories               0.447615  1.000000      -0.144163           -0.495216
# Caffeine (mg)         -0.554659 -0.144163       1.000000            0.636625
# caffeine_per_100ml    -0.984828 -0.495216       0.636625            1.000000
# calories_per_100ml    -0.477444  0.570325       0.349663            0.419014
#
#                     calories_per_100ml
# Volume (ml)                  -0.477444
# Calories                      0.570325
# Caffeine (mg)                 0.349663
# caffeine_per_100ml            0.419014
# calories_per_100ml            1.000000

# %%
#Scatter graph volumn vs caffeine
plt.figure(figsize=(10,6))
x=df["Volume (ml)"].values
y=df["Caffeine (mg)"].values
plt.scatter(x,y)
plt.show()

# %%
#Scatter graph volumn vs caffeine per 100 ml

plt.figure(figsize=(10,6))
x=df2["Volume (ml)"].values
y=df2["caffeine_per_100ml"].values
plt.scatter(x,y)
plt.show()

# %%
df2.type.unique()
# Out:
# array(['Coffee', 'Energy Drinks', 'Energy Shots', 'Soft Drinks', 'Tea',
#        'Water'], dtype=object)

# %%
types=['Coffee', 'Energy Drinks', 'Energy Shots', 'Soft Drinks', 'Tea',
       'Water']
df_coffee=df2.loc[df2.type=="Coffee"].reset_index()
df_coffee
# Out:
#      index                          drink  Volume (ml)  Calories  \
# 0        0                   Costa Coffee   256.993715         0
# 1        1    Coffee Friend Brewed Coffee   250.191810         0
# 2        2             Hell Energy Coffee   250.191810       150
# 3        3             Killer Coffee (AU)   250.191810         0
# 4        4                   Nescafe Gold   250.191810         0
# ..     ...                            ...          ...       ...
# 168    168  Nescafe 3 in 1 Instant Coffee   177.441000        74
# 169    169           Gloria Jean's Coffee    59.975058         0
# 170    170                Biggby Espresso    59.147000         0
# 171    171         Greek Coffee (Metrios)    59.147000        25
# 172    172                 Turkish Coffee    59.147000        20
#
#      Caffeine (mg)    type  caffeine_per_100ml  calories_per_100ml
# 0              277  Coffee          107.784737            0.000000
# 1              145  Coffee           57.955534            0.000000
# 2              100  Coffee           39.969334           59.954001
# 3              430  Coffee          171.868136            0.000000
# 4               66  Coffee           26.379760            0.000000
# ..             ...     ...                 ...                 ...
# 168             50  Coffee           28.178380           41.704003
# 169             67  Coffee          111.713106            0.000000
# 170            100  Coffee          169.070283            0.000000
# 171             50  Coffee           84.535141           42.267571
# 172             50  Coffee           84.535141           33.814057
#
# [173 rows x 8 columns]

# %%
#df_coffee.plot()

# %%
#Scatter graph volumn vs caffeine for coffee

plt.figure(figsize=(10,6))
x_coffee=df_coffee["Volume (ml)"].values
y_coffee=df_coffee["caffeine_per_100ml"].values
plt.scatter(x,y)
plt.show()

# %%
types=['Coffee', 'Energy Drinks', 'Energy Shots', 'Soft Drinks', 'Tea',
       'Water']
df_energyd=df2.loc[df2.type=="Energy Drinks"].reset_index()
df_energyd
# Out:
#      index                        drink  Volume (ml)  Calories  Caffeine (mg)  \
# 0      173        28 Black Energy Drink    250.19181       125             80
# 1      174       4 Purpose Energy Drink    250.19181        70             70
# 2      175          BEEBAD Energy Drink    250.19181       110             80
# 3      176     Black Bruin Energy Drink    250.19181       122             38
# 4      177        Blu Frog Energy Drink    250.19181        90             80
# ..     ...                          ...          ...       ...            ...
# 214    387             Redline Princess    236.58800         0            300
# 215    388  Redline Xtreme Energy Drink    236.58800         0            316
# 216    389    Roaring Lion Energy Drink    236.58800       100             77
# 217    390       Spark Energy Drink Mix    236.58800        15            120
# 218    391             V8 +Energy Drink    236.58800       140             80
#
#               type  caffeine_per_100ml  calories_per_100ml
# 0    Energy Drinks           31.975467           49.961667
# 1    Energy Drinks           27.978534           27.978534
# 2    Energy Drinks           31.975467           43.966267
# 3    Energy Drinks           15.188347           48.762587
# 4    Energy Drinks           31.975467           35.972401
# ..             ...                 ...                 ...
# 214  Energy Drinks          126.802712            0.000000
# 215  Energy Drinks          133.565523            0.000000
# 216  Energy Drinks           32.546029           42.267571
# 217  Energy Drinks           50.721085            6.340136
# 218  Energy Drinks           33.814057           59.174599
#
# [219 rows x 8 columns]

# %%
#Scatter graph volumn vs caffeine for energy drinks

plt.figure(figsize=(10,6))
x_energyd=df_energyd["Volume (ml)"].values
y_energyd=df_energyd["caffeine_per_100ml"].values
plt.scatter(x,y)
plt.show()

# %%
types=['Coffee', 'Energy Drinks', 'Energy Shots', 'Soft Drinks', 'Tea',
       'Water']
df_energys=df2.loc[df2.type=="Energy Shots"].reset_index()
df_energys
# Out:
#     index                          drink  Volume (ml)  Calories  \
# 0     392       Spike Energy Double Shot   125.983110         0
# 1     393     Zombie Blood Energy Potion   100.549900        25
# 2     394        Proper Wild Energy Shot    73.933750        25
# 3     395                Redline Max 300    73.933750         0
# 4     396                  5 Hour Energy    57.076855         4
# 5     397   5 Hour Energy Extra Strength    57.076855         0
# 6     398                 E6 Energy Shot    57.076855         0
# 7     399  Eternal Energy Extra Strength    57.076855         0
# 8     400            Eternal Energy Shot    57.076855         0
# 9     401            Woke Up Energy Shot    57.076855         0
# 10    402         Equip Pure Energy Shot    53.232300        35
# 11    403             Mana Energy Potion    49.979215        25
# 12    404           Clif Shot Energy Gel    35.488200       100
# 13    405        Screamin Energy Max Hit    18.039835        40
# 14    406         Vital 4U Liquid Energy    14.786750        34
# 15    407      Kaffn8 Liquified Caffeine     7.393375         0
# 16    408                      Bang Shot    88.720500         0
# 17    409            Redline Xtreme Shot    88.720500         5
# 18    410           7-Eleven Energy Shot    59.147000         0
# 19    411      Advocare Slam Energy Shot    59.147000        10
# 20    412            Balance Active Shot    59.147000        80
# 21    413            Balance Energy Shot    59.147000        77
# 22    414      Forto Organic Coffee Shot    59.147000        35
# 23    415           Kirkland Energy Shot    59.147000         5
# 24    416             Neu Nootropic Shot    59.147000         0
# 25    417          Nutramint Smart Serum    59.147000        45
# 26    418           Performance Caffeine    59.147000         0
# 27    419            Phoenix Energy Shot    59.147000         0
# 28    420        Red Thunder Energy Shot    59.147000         0
# 29    421     Red Thunder Extra Strength    59.147000         0
# 30    422    Reed's Ginger Energize Shot    59.147000        24
# 31    423             Rip It Energy Shot    59.147000         0
# 32    424    Stacker Extreme Energy Shot    59.147000         0
# 33    425                   Tweaker Shot    59.147000         0
# 34    426                 TruBrain Extra    29.573500        25
# 35    427             X-Mode Energy Shot    29.573500         0
#
#     Caffeine (mg)          type  caffeine_per_100ml  calories_per_100ml
# 0             350  Energy Shots          277.815018            0.000000
# 1              80  Energy Shots           79.562486           24.863277
# 2             180  Energy Shots          243.461207           33.814057
# 3             300  Energy Shots          405.768678            0.000000
# 4             200  Energy Shots          350.404731            7.008095
# 5             230  Energy Shots          402.965440            0.000000
# 6             235  Energy Shots          411.725558            0.000000
# 7             280  Energy Shots          490.566623            0.000000
# 8             230  Energy Shots          402.965440            0.000000
# 9             225  Energy Shots          394.205322            0.000000
# 10            100  Energy Shots          187.855869           65.749554
# 11             75  Energy Shots          150.062381           50.020794
# 12            100  Energy Shots          281.783804          281.783804
# 13            185  Energy Shots         1025.508271          221.731518
# 14            155  Energy Shots         1048.235752          229.935584
# 15             75  Energy Shots         1014.421695            0.000000
# 16            300  Energy Shots          338.140565            0.000000
# 17            300  Energy Shots          338.140565            5.635676
# 18            260  Energy Shots          439.582735            0.000000
# 19            120  Energy Shots          202.884339           16.907028
# 20            100  Energy Shots          169.070283          135.256226
# 21            150  Energy Shots          253.605424          130.184118
# 22            225  Energy Shots          380.408136           59.174599
# 23            180  Energy Shots          304.326509            8.453514
# 24            350  Energy Shots          591.745989            0.000000
# 25            200  Energy Shots          338.140565           76.081627
# 26            180  Energy Shots          304.326509            0.000000
# 27            280  Energy Shots          473.396791            0.000000
# 28            138  Energy Shots          233.316990            0.000000
# 29            230  Energy Shots          388.861650            0.000000
# 30            100  Energy Shots          169.070283           40.576868
# 31            120  Energy Shots          202.884339            0.000000
# 32            205  Energy Shots          346.594079            0.000000
# 33            275  Energy Shots          464.943277            0.000000
# 34            100  Energy Shots          338.140565           84.535141
# 35            150  Energy Shots          507.210848            0.000000

# %%
#Scatter graph volumn vs caffeine for energy shorts

plt.figure(figsize=(10,6))
x_energys=df_energys["Volume (ml)"].values
y_energys=df_energys["caffeine_per_100ml"].values
plt.scatter(x,y)
plt.show()

# %%
types=['Coffee', 'Energy Drinks', 'Energy Shots', 'Soft Drinks', 'Tea',
       'Water']
df_soft=df2.loc[df2.type=="Soft Drinks"].reset_index()
df_soft
# Out:
#     index                     drink  Volume (ml)  Calories  Caffeine (mg)  \
# 0     428      Red Bull Simply Cola    250.19181         0             32
# 1     429                 Afri Cola    330.04026       139             83
# 2     430           Fritz Kola (EU)    330.04026       135             83
# 3     431            Pepsi Max (UK)    330.04026         0             43
# 4     432         Premium Cola (EU)    330.04026       132             83
# ..    ...                       ...          ...       ...            ...
# 85    513         Wild Cherry Pepsi    354.88200       160             38
# 86    514                Zevia Cola    354.88200         0             45
# 87    515   Boost Nutritional Drink    236.58800       240              5
# 88    516  Mucho Mango Energy Drink    236.58800       100              0
# 89    517               Soda Stream    236.58800        40             31
#
#            type  caffeine_per_100ml  calories_per_100ml
# 0   Soft Drinks           12.790187            0.000000
# 1   Soft Drinks           25.148447           42.116074
# 2   Soft Drinks           25.148447           40.904101
# 3   Soft Drinks           13.028714            0.000000
# 4   Soft Drinks           25.148447           39.995121
# ..          ...                 ...                 ...
# 85  Soft Drinks           10.707785           45.085409
# 86  Soft Drinks           12.680271            0.000000
# 87  Soft Drinks            2.113379          101.442170
# 88  Soft Drinks            0.000000           42.267571
# 89  Soft Drinks           13.102947           16.907028
#
# [90 rows x 8 columns]

# %%
#Scatter graph volumn vs caffeine for soft drinks

plt.figure(figsize=(10,6))
x_soft=df_soft["Volume (ml)"].values
y_soft=df_soft["caffeine_per_100ml"].values
plt.scatter(x,y)
plt.show()

# %%
types=['Coffee', 'Energy Drinks', 'Energy Shots', 'Soft Drinks', 'Tea',
       'Water']
df_tea=df2.loc[df2.type=="Tea"].reset_index()
df_tea
# Out:
#     index                        drink  Volume (ml)  Calories  Caffeine (mg)  \
# 0     518            PG Tips Black Tea    200.50833         0             50
# 1     519        Sencha Green Tea Shot    189.27040         0             40
# 2     520       Xingtea Iced Green Tea    694.97725        50            110
# 3     521                Gold Peak Tea    547.10975         0             48
# 4     522           Pure Leaf Iced Tea    547.10975       160             69
# ..    ...                          ...          ...       ...            ...
# 61    579               Yerba Mate Tea    236.58800         0             40
# 62    580          YMateina Yerba Mate    236.58800         0             80
# 63    581  Zest Highly Caffeinated Tea    236.58800         0            150
# 64    582              Oregon Chai Tea    177.44100       130             45
# 65    583                 Pacific Chai    177.44100        90             29
#
#    type  caffeine_per_100ml  calories_per_100ml
# 0   Tea           24.936620            0.000000
# 1   Tea           21.133785            0.000000
# 2   Tea           15.827856            7.194480
# 3   Tea            8.773377            0.000000
# 4   Tea           12.611729           29.244589
# ..  ...                 ...                 ...
# 61  Tea           16.907028            0.000000
# 62  Tea           33.814057            0.000000
# 63  Tea           63.401356            0.000000
# 64  Tea           25.360542           73.263789
# 65  Tea           16.343461           50.721085
#
# [66 rows x 8 columns]

# %%
#Scatter graph volumn vs caffeine for tea

plt.figure(figsize=(10,6))
x_tea=df_tea["Volume (ml)"].values
y_tea=df_tea["caffeine_per_100ml"].values
plt.scatter(x,y)
plt.show()

# %%
types=['Coffee', 'Energy Drinks', 'Energy Shots', 'Soft Drinks', 'Tea',
       'Water']
df_water=df2.loc[df2.type=="Water"].reset_index()
df_water
# Out:
#     index                                 drink  Volume (ml)  Calories  \
# 0     584                      Perrier Energize   250.191810        35
# 1     585                               3 Water   499.792150         0
# 2     586                   Heroec Energy Water   499.792150         0
# 3     587       Caribou BOUsted Sparkling Water   340.095250         0
# 4     588                Phocus Sparkling Water   340.095250         0
# 5     589  Poland Spring Sparkling Energy Water   340.095250        35
# 6     590               Perrier Sparkling Water   329.744525         0
# 7     591                   VitaminWater Energy   591.470000       100
# 8     592          VitaRain Zero Enhanced Water   591.470000         0
# 9     593                             Water Joe   591.470000         0
# 10    594               Polar Frost Plus Energy   502.749500        10
# 11    595              Hint Caffeine Kick Water   473.176000         0
# 12    596               Sparkling Ice +Caffeine   473.176000         5
# 13    597                   AHA Sparkling Water   354.882000         0
# 14    598                  Arti Sparkling Water   354.882000         0
# 15    599               Bubbl'r Sparkling Water   354.882000         5
# 16    600          Bubly Bounce Sparkling Water   354.882000         0
# 17    601                 Bubly Sparkling Water   354.882000         0
# 18    602           GURU Sparkling Energy Water   354.882000         0
# 19    603              La Croix Sparkling Water   354.882000         0
# 20    604             Limitless Sparkling Water   354.882000         0
# 21    605              Pep Talk Sparkling Water   354.882000         0
# 22    606                   Polar Seltzer Water   354.882000         0
# 23    607                Yerbae Sparkling Water   354.882000         0
# 24    608                           Tonic Water   295.735000       110
# 25    609             MiO Energy Water Enhancer   236.588000         0
#
#     Caffeine (mg)   type  caffeine_per_100ml  calories_per_100ml
# 0              99  Water           39.569641           13.989267
# 1              50  Water           10.004159            0.000000
# 2              60  Water           12.004990            0.000000
# 3              75  Water           22.052646            0.000000
# 4              75  Water           22.052646            0.000000
# 5              75  Water           22.052646           10.291235
# 6               0  Water            0.000000            0.000000
# 7              50  Water            8.453514           16.907028
# 8              42  Water            7.100952            0.000000
# 9              70  Water           11.834920            0.000000
# 10             67  Water           13.326716            1.989062
# 11             60  Water           12.680271            0.000000
# 12             70  Water           14.793650            1.056689
# 13             30  Water            8.453514            0.000000
# 14            120  Water           33.814057            0.000000
# 15             69  Water           19.443082            1.408919
# 16             35  Water            9.862433            0.000000
# 17              0  Water            0.000000            0.000000
# 18            100  Water           28.178380            0.000000
# 19              0  Water            0.000000            0.000000
# 20             35  Water            9.862433            0.000000
# 21             55  Water           15.498109            0.000000
# 22              0  Water            0.000000            0.000000
# 23            100  Water           28.178380            0.000000
# 24              0  Water            0.000000           37.195462
# 25             60  Water           25.360542            0.000000

# %%
#Scatter graph volumn vs caffeine for water

plt.figure(figsize=(10,6))
x_water=df_water["Volume (ml)"].values
y_water=df_water["caffeine_per_100ml"].values
plt.scatter(x,y)
plt.show()

# %%
# keys=['Coffee', 'Energy Drinks', 'Energy Shots', 'Soft Drinks', 'Tea','Water']
# caffeine_100ml_dict={
#     'Coffee': y_coffee,
#     'Energy Drinks': y_energyd,
#     'Energy Shots': y_energys,
#     'Soft Drinks': y_soft,
#     'Tea':y_tea,
#     'Water': y_water}

# df_caffeine_per_100ml = pd.DataFrame(caffeine_100ml_dict)
# plt.rcParams["figure.figsize"] = [20, 15]
# plt.rcParams["figure.autolayout"] = True
# ax = boxdata[keys].plot(kind='box')
# plt.show()

# %%
#plt.figure(figsize=(20,6))
fig, (ax1,ax2,ax3,ax4,ax5,ax6) = plt.subplots(1, 6)
fig.suptitle('Horizontally stacked subplots')
fig.set_size_inches(20,12)

ax1.boxplot(y_coffee)
ax1.set_ylim([0,600])
ax2.boxplot(y_energyd)
ax2.set_ylim([0,600])
ax3.boxplot(y_energys)
ax3.set_ylim([0,600])
ax4.boxplot(y_soft)
ax4.set_ylim([0,600])
ax5.boxplot(y_tea)
ax5.set_ylim([0,600])
ax6.boxplot(y_water)
ax6.set_ylim([0,600])

plt.show()

# %%
y_coffee.shape
# Out:
# (173,)

# %%
y_energyd.shape
# Out:
# (219,)

# %%
y_energys.shape
# Out:
# (36,)

# %%
y_soft.shape
# Out:
# (90,)

# %%
y_tea.shape
# Out:
# (66,)

# %%
y_water.shape
# Out:
# (26,)

# %%
plt.boxplot([pd.DataFrame(x_coffee),pd.DataFrame(x_energyd)])

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [51], in <cell line: 1>()
# ----> 1 plt.boxplot([pd.DataFrame(x_coffee),pd.DataFrame(x_energyd)])
#       3 plt.show()
#
# File ~\anaconda3\lib\site-packages\matplotlib\pyplot.py:2428, in boxplot(x, notch, sym, vert, whis, positions, widths, patch_artist, bootstrap, usermedians, conf_intervals, meanline, showmeans, showcaps, showbox, showfliers, boxprops, labels, flierprops, medianprops, meanprops, capprops, whiskerprops, manage_ticks, autorange, zorder, data)
#    2418 @_copy_docstring_and_deprecators(Axes.boxplot)
#    2419 def boxplot(
#    2420         x, notch=None, sym=None, vert=None, whis=None,
#    (...)
#    2426         whiskerprops=None, manage_ticks=True, autorange=False,
#    2427         zorder=None, *, data=None):
# -> 2428     return gca().boxplot(
#    2429         x, notch=notch, sym=sym, vert=vert, whis=whis,
#    2430         positions=positions, widths=widths, patch_artist=patch_artist,
#    2431         bootstrap=bootstrap, usermedians=usermedians,
#    2432         conf_intervals=conf_intervals, meanline=meanline,
#    2433         showmeans=showmeans, showcaps=showcaps, showbox=showbox,
#    2434         showfliers=showfliers, boxprops=boxprops, labels=labels,
#    2435         flierprops=flierprops, medianprops=medianprops,
#    2436         meanprops=meanprops, capprops=capprops,
#    2437         whiskerprops=whiskerprops, manage_ticks=manage_ticks,
#    2438         autorange=autorange, zorder=zorder,
#    2439         **({"data": data} if data is not None else {}))
#
# File ~\anaconda3\lib\site-packages\matplotlib\__init__.py:1412, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1409 @functools.wraps(func)
#    1410 def inner(ax, *args, data=None, **kwargs):
#    1411     if data is None:
# -> 1412         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1414     bound = new_sig.bind(ax, *args, **kwargs)
#    1415     auto_label = (bound.arguments.get(label_namer)
#    1416                   or bound.kwargs.get(label_namer))
#
# File ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:3711, in Axes.boxplot(self, x, notch, sym, vert, whis, positions, widths, patch_artist, bootstrap, usermedians, conf_intervals, meanline, showmeans, showcaps, showbox, showfliers, boxprops, labels, flierprops, medianprops, meanprops, capprops, whiskerprops, manage_ticks, autorange, zorder)
#    3708 if bootstrap is None:
#    3709     bootstrap = rcParams['boxplot.bootstrap']
# -> 3711 bxpstats = cbook.boxplot_stats(x, whis=whis, bootstrap=bootstrap,
#    3712                                labels=labels, autorange=autorange)
#    3713 if notch is None:
#    3714     notch = rcParams['boxplot.notch']
#
# File ~\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:1155, in boxplot_stats(X, whis, bootstrap, labels, autorange)
#    1152 bxpstats = []
#    1154 # convert X to a list of lists
# -> 1155 X = _reshape_2D(X, "X")
#    1157 ncols = len(X)
#    1158 if labels is None:
#
# File ~\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:1398, in _reshape_2D(X, name)
#    1396     nd = np.ndim(xi)
#    1397     if nd > 1:
# -> 1398         raise ValueError(f'{name} must have 2 or fewer dimensions')
#    1399     result.append(xi.reshape(-1))
#    1401 if is_1d:
#    1402     # 1D array of scalars: directly return it.
#
# ValueError: X must have 2 or fewer dimensions

# %%
# #caffeine vs type vs volume

# #Groupby type
# df_drink_type = df[['type','Volume (ml)','Calories','Caffeine (mg)']]
# drinks_type_groupby = df_drink_type.groupby(['type'])
# drinks_type = drinks_type_groupby['type'] 

# #caffeine
# drinks_caffeine = drinks_type_groupby['Caffeine (mg)'].mean()

# #volume
# drinks_volume =drinks_type_groupby['Volume (ml)'].mean()

# #calories
# drinks_calories =drinks_type_groupby['Calories'].mean()


# #create a DataFrame
# summary=pd.DataFrame({
#     "Caffeine":drinks_caffeine,
#     "Volume":drinks_volume,
#     "Calories":drinks_calories
# })

# summary
